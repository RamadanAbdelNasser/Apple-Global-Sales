# %% [markdown]
# # Apple Global Sales

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
import plotly.express as px
import streamlit as st

# %%
df = pd.read_csv('../Data/Raw Data/apple_global_sales_dataset.csv')

# %%
df
# Out:
#              sale_id   sale_date  year quarter     month    country  \
# 0      APPL-00000001  2022-01-03  2022      Q1   January  Argentina
# 1      APPL-00000002  2022-01-04  2022      Q1   January  Argentina
# 2      APPL-00000003  2022-05-18  2022      Q2       May  Argentina
# 3      APPL-00000004  2022-05-23  2022      Q2       May  Argentina
# 4      APPL-00000005  2022-07-13  2022      Q3      July  Argentina
# ...              ...         ...   ...     ...       ...        ...
# 11495  APPL-00011496  2024-02-08  2024      Q1  February    Vietnam
# 11496  APPL-00011497  2024-02-15  2024      Q1  February    Vietnam
# 11497  APPL-00011498  2024-08-28  2024      Q3    August    Vietnam
# 11498  APPL-00011499  2024-08-31  2024      Q3    August    Vietnam
# 11499  APPL-00011500  2024-10-10  2024      Q4   October    Vietnam
#
#               region          city              product_name     category  \
# 0      South America  Buenos Aires         AirPods (3rd Gen)      AirPods
# ...

# %%
df.columns
# Out:
# Index(['sale_id', 'sale_date', 'year', 'quarter', 'month', 'country', 'region',
#        'city', 'product_name', 'category', 'storage', 'color',
#        'unit_price_usd', 'discount_pct', 'units_sold', 'discounted_price_usd',
#        'revenue_usd', 'currency', 'fx_rate_to_usd', 'revenue_local_currency',
#        'sales_channel', 'payment_method', 'customer_segment',
#        'customer_age_group', 'previous_device_os', 'customer_rating',
#        'return_status'],
#       dtype='object')

# %%
df['sale_id'].unique()
# Out:
# array(['APPL-00000001', 'APPL-00000002', 'APPL-00000003', ...,
#        'APPL-00011498', 'APPL-00011499', 'APPL-00011500'],
#       shape=(11500,), dtype=object)

# %%
df['sale_id'].nunique()
# Out:
# 11500

# %%
df['sale_id'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Sales Time Columns

# %%
df['sale_date'].unique()
# Out:
# array(['2022-01-03', '2022-01-04', '2022-05-18', ..., '2024-04-06',
#        '2024-03-13', '2024-08-12'], shape=(1096,), dtype=object)

# %%
df['sale_date'].nunique()
# Out:
# 1096

# %%
df['sale_date'].isna().sum()
# Out:
# np.int64(0)

# %%
df['sale_date'].astype('date32[pyarrow]')
# Out:
# 0        2022-01-03
# 1        2022-01-04
# 2        2022-05-18
# 3        2022-05-23
# 4        2022-07-13
#             ...
# 11495    2024-02-08
# 11496    2024-02-15
# 11497    2024-08-28
# 11498    2024-08-31
# 11499    2024-10-10
# Name: sale_date, Length: 11500, dtype: date32[day][pyarrow]

# %%
df['year'].unique()
# Out:
# array([2022, 2023, 2024])

# %%
df['year'].dtype
# Out:
# dtype('int64')

# %%
df['quarter'].unique()
# Out:
# array(['Q1', 'Q2', 'Q3', 'Q4'], dtype=object)

# %%
df['month'].unique()
# Out:
# array(['January', 'May', 'July', 'August', 'February', 'March', 'April',
#        'September', 'November', 'June', 'October', 'December'],
#       dtype=object)

# %%
df.sample()
# Out:
#             sale_id   sale_date  year quarter      month  country  region  \
# 2548  APPL-00002549  2022-09-07  2022      Q3  September  Denmark  Europe
#
#          city   product_name category     storage     color  unit_price_usd  \
# 2548  Kolding  Mac mini (M2)      Mac  256 GB SSD  Midnight          581.36
#
#       discount_pct  units_sold  discounted_price_usd  revenue_usd currency  \
# 2548             5           5                552.29      2761.45      DKK
#
#       fx_rate_to_usd  revenue_local_currency    sales_channel payment_method  \
# 2548             6.9                19054.01  Corporate / B2B    Net Banking
#
#      customer_segment customer_age_group previous_device_os  customer_rating  \
# 2548         Business              18–24                NaN              3.2
#
#      return_status
# 2548          Kept

# %% [markdown]
# ## Sales Location Columns

# %%
df.columns
# Out:
# Index(['sale_id', 'sale_date', 'year', 'quarter', 'month', 'country', 'region',
#        'city', 'product_name', 'category', 'storage', 'color',
#        'unit_price_usd', 'discount_pct', 'units_sold', 'discounted_price_usd',
#        'revenue_usd', 'currency', 'fx_rate_to_usd', 'revenue_local_currency',
#        'sales_channel', 'payment_method', 'customer_segment',
#        'customer_age_group', 'previous_device_os', 'customer_rating',
#        'return_status'],
#       dtype='object')

# %%
df['country'].unique()
# Out:
# array(['Argentina', 'Australia', 'Austria', 'Bangladesh', 'Belgium',
#        'Brazil', 'Canada', 'Chile', 'China', 'Colombia', 'Denmark',
#        'Egypt', 'Finland', 'France', 'Germany', 'Hong Kong', 'India',
#        'Indonesia', 'Ireland', 'Italy', 'Japan', 'Kenya', 'Malaysia',
#        'Mexico', 'Netherlands', 'New Zealand', 'Nigeria', 'Norway',
#        'Pakistan', 'Philippines', 'Poland', 'Portugal', 'Russia',
#        'Saudi Arabia', 'Singapore', 'South Africa', 'South Korea',
#        'Spain', 'Sweden', 'Switzerland', 'Taiwan', 'Thailand', 'Turkey',
#        'UAE', 'United Kingdom', 'United States', 'Vietnam'], dtype=object)

# %%
df['country'].isna().sum()
# Out:
# np.int64(0)

# %%
df['region'].unique()
# Out:
# array(['South America', 'Oceania', 'Europe', 'Asia', 'North America',
#        'Africa', 'Europe/Asia', 'Middle East'], dtype=object)

# %%
df[df['region']=='Europe/Asia']
# Out:
#              sale_id   sale_date  year quarter     month country       region  \
# 7858   APPL-00007859  2022-01-11  2022      Q1   January  Russia  Europe/Asia
# 7859   APPL-00007860  2022-02-24  2022      Q1  February  Russia  Europe/Asia
# 7860   APPL-00007861  2022-03-07  2022      Q1     March  Russia  Europe/Asia
# 7861   APPL-00007862  2022-04-01  2022      Q2     April  Russia  Europe/Asia
# 7862   APPL-00007863  2022-04-15  2022      Q2     April  Russia  Europe/Asia
# ...              ...         ...   ...     ...       ...     ...          ...
# 10556  APPL-00010557  2024-01-27  2024      Q1   January  Turkey  Europe/Asia
# 10557  APPL-00010558  2024-02-25  2024      Q1  February  Turkey  Europe/Asia
# 10558  APPL-00010559  2024-03-16  2024      Q1     March  Turkey  Europe/Asia
# 10559  APPL-00010560  2024-07-01  2024      Q3      July  Turkey  Europe/Asia
# 10560  APPL-00010561  2024-10-07  2024      Q4   October  Turkey  Europe/Asia
#
# ...

# %%
df['city'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Sales Product Columns

# %%
df.columns
# Out:
# Index(['sale_id', 'sale_date', 'year', 'quarter', 'month', 'country', 'region',
#        'city', 'product_name', 'category', 'storage', 'color',
#        'unit_price_usd', 'discount_pct', 'units_sold', 'discounted_price_usd',
#        'revenue_usd', 'currency', 'fx_rate_to_usd', 'revenue_local_currency',
#        'sales_channel', 'payment_method', 'customer_segment',
#        'customer_age_group', 'previous_device_os', 'customer_rating',
#        'return_status'],
#       dtype='object')

# %%
df['product_name'].unique()
# Out:
# array(['AirPods (3rd Gen)', 'USB-C Woven Charge Cable',
#        'Apple Watch Series 8', 'MacBook Pro 14-inch (M3)',
#        'Apple Watch Ultra 2', 'Magic Keyboard', 'iPhone 15 Pro Max',
#        'Apple TV 4K (3rd Gen)', 'iPad Mini (6th Gen)',
#        'iPad (10th Generation)', 'iPad Pro 12.9-inch (M2)',
#        'iPhone 15 Pro', 'iPhone 15 Plus', 'iPhone 13 Pro',
#        'MacBook Air 13-inch (M2)', 'iPad Pro 11-inch (M2)',
#        'Apple Pencil (2nd Gen)', 'iPad Air (M1)', 'iPhone SE (3rd Gen)',
#        'Magic Mouse', 'AirPods Pro (2nd Gen)', 'iPhone 14',
#        'iPhone 13 Mini', 'iPhone 15', 'MacBook Air 15-inch (M2)',
#        'MagSafe Charger', 'iPhone 13', 'iPhone 14 Plus', 'Mac mini (M2)',
#        'Apple Watch SE (2nd Gen)', 'Apple Pencil (1st Gen)',
#        'AirPods (2nd Gen)', 'Magic Trackpad', 'iPhone 13 Pro Max',
#        'MacBook Pro 16-inch (M3 Pro)', 'AirPods Max', 'HomePod mini',
#        'iPhone 14 Pro Max', 'Apple Watch Series 9', 'Mac Pro (M2 Ultra)',
# ...

# %%
df['product_name'].isna().sum()
# Out:
# np.int64(0)

# %%
df['category'].unique()
# Out:
# array(['AirPods', 'Accessories', 'Apple Watch', 'Mac', 'iPhone', 'iPad'],
#       dtype=object)

# %%
df['storage'].unique()
# Out:
# array([nan, '1 TB SSD', '64 GB', '128 GB', '256 GB', '1 TB', '2 TB SSD',
#        '512 GB', '512 GB SSD', '2 TB', '256 GB SSD'], dtype=object)

# %%
df['storage'].fillna('Not Applicable',inplace=True)
# Out:
# C:\Users\Majid Mokhtar\AppData\Local\Temp\ipykernel_12428\4122581186.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['storage'].fillna('Not Applicable',inplace=True)

# %%
df['storage'].unique()
# Out:
# array(['Not Applicable', '1 TB SSD', '64 GB', '128 GB', '256 GB', '1 TB',
#        '2 TB SSD', '512 GB', '512 GB SSD', '2 TB', '256 GB SSD'],
#       dtype=object)

# %%
df['color'].unique()
# Out:
# array(['Starlight', 'Black', 'Titanium', 'Midnight', 'Silver', 'White',
#        'Space Gray', 'Black Titanium', 'Blue', 'Blue Titanium', 'Purple',
#        'Sky', 'Product Red', 'Deep Purple', 'Gold', 'Yellow', 'Natural',
#        'Natural Titanium', 'Green', 'White Titanium'], dtype=object)

# %% [markdown]
# ## Sales Numbers Columns

# %%
df.columns
# Out:
# Index(['sale_id', 'sale_date', 'year', 'quarter', 'month', 'country', 'region',
#        'city', 'product_name', 'category', 'storage', 'color',
#        'unit_price_usd', 'discount_pct', 'units_sold', 'discounted_price_usd',
#        'revenue_usd', 'currency', 'fx_rate_to_usd', 'revenue_local_currency',
#        'sales_channel', 'payment_method', 'customer_segment',
#        'customer_age_group', 'previous_device_os', 'customer_rating',
#        'return_status'],
#       dtype='object')

# %%
df['unit_price_usd'].unique()
# Out:
# array([ 159.27,   29.99,  293.92, ...,  759.97,  438.99, 1271.57],
#       shape=(10616,))

# %%
df['unit_price_usd'].isna().sum()
# Out:
# np.int64(0)

# %%
df['unit_price_usd'].dtype
# Out:
# dtype('float64')

# %%
df['discount_pct'].unique()
# Out:
# array([ 7, 15,  0,  5,  3,  2, 10])

# %%
df['discount_pct'].dtype
# Out:
# dtype('int64')

# %%
df['units_sold'].unique()
# Out:
# array([1, 5, 4, 2, 3, 8, 7, 6])

# %%
df['units_sold'].dtype
# Out:
# dtype('int64')

# %%
df['discounted_price_usd'].unique()
# Out:
# array([ 148.12,   25.49,  293.92, ...,  706.77,  438.99, 1182.56],
#       shape=(10787,))

# %%
df['discounted_price_usd'].isna().sum()
# Out:
# np.int64(0)

# %%
df['discounted_price_usd'].dtype
# Out:
# dtype('float64')

# %%
df['units_sold'].unique()
# Out:
# array([1, 5, 4, 2, 3, 8, 7, 6])

# %%
df['discounted_price_usd'].unique()
# Out:
# array([ 148.12,   25.49,  293.92, ...,  706.77,  438.99, 1182.56],
#       shape=(10787,))

# %%
df['discounted_price_usd'].isna().sum()
# Out:
# np.int64(0)

# %%
df['discounted_price_usd'].dtype
# Out:
# dtype('float64')

# %%
df['revenue_usd'].unique()
# Out:
# array([ 148.12,  127.45, 1175.68, ..., 3533.85,  438.99, 1182.56],
#       shape=(11142,))

# %%
df['revenue_usd'].isna().sum()
# Out:
# np.int64(0)

# %%
df['revenue_usd'].dtype
# Out:
# dtype('float64')

# %%
df['currency'].unique()
# Out:
# array(['ARS', 'AUD', 'EUR', 'BDT', 'BRL', 'CAD', 'CLP', 'CNY', 'COP',
#        'DKK', 'EGP', 'HKD', 'INR', 'IDR', 'JPY', 'KES', 'MYR', 'MXN',
#        'NZD', 'NGN', 'NOK', 'PKR', 'PHP', 'PLN', 'RUB', 'SAR', 'SGD',
#        'ZAR', 'KRW', 'SEK', 'CHF', 'TWD', 'THB', 'TRY', 'AED', 'GBP',
#        'USD', 'VND'], dtype=object)

# %%
df['fx_rate_to_usd'].unique()
# Out:
# array([9.070e+02, 1.530e+00, 9.200e-01, 1.100e+02, 4.970e+00, 1.360e+00,
#        9.600e+02, 7.240e+00, 3.960e+03, 6.900e+00, 3.090e+01, 7.820e+00,
#        8.350e+01, 1.570e+04, 1.498e+02, 1.290e+02, 4.710e+00, 1.715e+01,
#        1.630e+00, 1.550e+03, 1.065e+01, 2.790e+02, 5.650e+01, 3.970e+00,
#        9.150e+01, 3.750e+00, 1.340e+00, 1.890e+01, 1.328e+03, 1.055e+01,
#        8.800e-01, 3.180e+01, 3.520e+01, 3.050e+01, 3.670e+00, 7.900e-01,
#        1.000e+00, 2.450e+04])

# %%
df['fx_rate_to_usd'].dtype
# Out:
# dtype('float64')

# %%
df['revenue_local_currency'].unique()
# Out:
# array([  134344.84,   115597.15,  1066341.76, ..., 86579325.  ,
#        10755255.  , 28972720.  ], shape=(11445,))

# %%
df['revenue_local_currency'].isna().sum()
# Out:
# np.int64(0)

# %%
df['revenue_local_currency'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## Sales Customers Columns

# %%
df.columns
# Out:
# Index(['sale_id', 'sale_date', 'year', 'quarter', 'month', 'country', 'region',
#        'city', 'product_name', 'category', 'storage', 'color',
#        'unit_price_usd', 'discount_pct', 'units_sold', 'discounted_price_usd',
#        'revenue_usd', 'currency', 'fx_rate_to_usd', 'revenue_local_currency',
#        'sales_channel', 'payment_method', 'customer_segment',
#        'customer_age_group', 'previous_device_os', 'customer_rating',
#        'return_status'],
#       dtype='object')

# %%
df['sales_channel'].unique()
# Out:
# array(['Third-Party Retailer', 'Authorized Reseller', 'Corporate / B2B',
#        'Carrier Store', 'Apple Store', 'Online (Apple.com)'], dtype=object)

# %%
df['payment_method'].unique()
# Out:
# array(['Cash', 'Debit Card', 'Credit Card', 'Net Banking', 'Gift Card',
#        'Apple Pay', 'EMI / Installment'], dtype=object)

# %%
df['customer_segment'].unique()
# Out:
# array(['Government', 'Business', 'Individual', 'Education'], dtype=object)

# %%
df['customer_age_group'].unique()
# Out:
# array(['45–54', '18–24', '55+', '35–44', '25–34'], dtype=object)

# %%
df['previous_device_os'].unique()
# Out:
# array([nan, 'iOS 16', 'New User', 'Other', 'iOS 15', 'Android', 'iOS 17'],
#       dtype=object)

# %%
df['previous_device_os'].isna().mean()
# Out:
# np.float64(0.7005217391304348)

# %%
df['previous_device_os'].fillna('No Previous Device',inplace=True)
# Out:
# C:\Users\Majid Mokhtar\AppData\Local\Temp\ipykernel_12428\983133987.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_device_os'].fillna('No Previous Device',inplace=True)

# %%
df['previous_device_os'].unique()
# Out:
# array(['No Previous Device', 'iOS 16', 'New User', 'Other', 'iOS 15',
#        'Android', 'iOS 17'], dtype=object)

# %% [markdown]
# ## Sales Quality Columns

# %%
df.columns
# Out:
# Index(['sale_id', 'sale_date', 'year', 'quarter', 'month', 'country', 'region',
#        'city', 'product_name', 'category', 'storage', 'color',
#        'unit_price_usd', 'discount_pct', 'units_sold', 'discounted_price_usd',
#        'revenue_usd', 'currency', 'fx_rate_to_usd', 'revenue_local_currency',
#        'sales_channel', 'payment_method', 'customer_segment',
#        'customer_age_group', 'previous_device_os', 'customer_rating',
#        'return_status'],
#       dtype='object')

# %%
df['customer_rating'].unique()
# Out:
# array([4.1, 4.8, 4.3, nan, 4.9, 3.6, 4.7, 4.4, 3.4, 4.5, 3.9, 4.6, 3.7,
#        3.8, 3.1, 5. , 4. , 3.5, 3.3, 4.2, 3.2, 3. ])

# %%
df['customer_rating'].isna().sum()
# Out:
# np.int64(3360)

# %%
df['customer_rating'].isna().mean()
# Out:
# np.float64(0.2921739130434783)

# %%
df['customer_rating'].dtype
# Out:
# dtype('float64')

# %%
df.insert(26,'has_rating',df['customer_rating'].notna())

# %%
df['customer_rating'] = df['customer_rating'].fillna(0)

# %%
df['customer_rating'].unique()
# Out:
# array([4.1, 4.8, 4.3, 0. , 4.9, 3.6, 4.7, 4.4, 3.4, 4.5, 3.9, 4.6, 3.7,
#        3.8, 3.1, 5. , 4. , 3.5, 3.3, 4.2, 3.2, 3. ])

# %%
df['return_status'].unique()
# Out:
# array(['Kept', 'Exchanged', 'Returned'], dtype=object)

# %% [markdown]
# ## Saving File

# %%
df1 = df.to_csv('../Data/Clean Data/apple_global_sales_cleaned_data.csv')

# %%
df
# Out:
#              sale_id   sale_date  year quarter     month    country  \
# 0      APPL-00000001  2022-01-03  2022      Q1   January  Argentina
# 1      APPL-00000002  2022-01-04  2022      Q1   January  Argentina
# 2      APPL-00000003  2022-05-18  2022      Q2       May  Argentina
# 3      APPL-00000004  2022-05-23  2022      Q2       May  Argentina
# 4      APPL-00000005  2022-07-13  2022      Q3      July  Argentina
# ...              ...         ...   ...     ...       ...        ...
# 11495  APPL-00011496  2024-02-08  2024      Q1  February    Vietnam
# 11496  APPL-00011497  2024-02-15  2024      Q1  February    Vietnam
# 11497  APPL-00011498  2024-08-28  2024      Q3    August    Vietnam
# 11498  APPL-00011499  2024-08-31  2024      Q3    August    Vietnam
# 11499  APPL-00011500  2024-10-10  2024      Q4   October    Vietnam
#
#               region          city              product_name     category  \
# 0      South America  Buenos Aires         AirPods (3rd Gen)      AirPods
# ...
